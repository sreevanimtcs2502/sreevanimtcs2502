# %% [markdown]
# <a href="https://colab.research.google.com/github/sreevanimtcs2502/sreevanimtcs2502/blob/main/NLPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-whisper
# !pip install -q transformers
# !pip install -q googletrans==4.0.0-rc1
# !pip install -q torch
# !pip install -q nltk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 5.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -q openai-whisper transformers sentencepiece torch nltk
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.28.1 which is incompatible.

# %%
# !pip install -q --upgrade transformers sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 29.2 MB/s eta 0:00:00

# %%
# !pip uninstall -y transformers
# !pip install -q transformers==4.40.2 sentencepiece
# Out:
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 75.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.2.3 requires transformers<6.0.0,>=4.41.0, but you have transformers 4.40.2 which is incompatible.

# %%
# !pip install gTTS

from gtts import gTTS

text = """
అందరికీ నమస్కారం.
ఈ రోజు నేను ప్రకృతి గురించి మాట్లాడుతున్నాను.
ప్రకృతి మన జీవితానికి చాలా ముఖ్యమైనది.
అడవులు నదులు మరియు సముద్రాలు భూమిని అందంగా ఉంచుతాయి.
చెట్లు మనకు ఆక్సిజన్ ఇస్తాయి.
నదులు మనకు నీటిని అందిస్తాయి.
ప్రకృతిని కాపాడటం మన బాధ్యత.
మనము చెట్లు నాటాలి.
నీటిని ఆదా చేయాలి.
అప్పుడు భవిష్యత్తు తరాలకు మంచి భూమిని ఇవ్వగలము.
"""

tts = gTTS(text=text, lang="te", slow=True)

tts.save("telugu_nature_slow.wav")

print("Audio file created: telugu_nature_slow.wav")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typer 0.24.1 requires click>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...
# Audio file created: telugu_nature_slow.wav

# %%
# !pip install -q openai-whisper torch torchaudio gradio

import torch
import whisper
import gradio as gr
from transformers import pipeline

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using:", device)

# Load Whisper model
whisper_model = whisper.load_model("base")

# Load summarization model
summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn",
    device=0 if device=="cuda" else -1
)

def telugu_to_english_pipeline(audio):

    # Telugu speech → English translation
    result = whisper_model.transcribe(
        audio,
        task="translate",
        language="te"
    )

    english_text = result["text"]

    # Summarize
    summary = summarizer(
        english_text,
        max_length=120,
        min_length=40,
        do_sample=False
    )[0]["summary_text"]

    return english_text, summary


iface = gr.Interface(
    fn=telugu_to_english_pipeline,
    inputs=gr.Audio(sources=["upload","microphone"], type="filepath"),
    outputs=[
        gr.Textbox(label="English Transcript"),
        gr.Textbox(label="Summary")
    ],
    title="Telugu Audio → English Summary"
)

iface.launch(share=True)
# Out:
# Using: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://509c6ac4faae4e04e0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://509c6ac4faae4e04e0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
